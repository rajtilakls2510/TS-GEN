# %%
import pandas as pd
import numpy as np

# %%
user_traits=pd.read_csv('../Data/UserTraits.csv')
teachers_characters=pd.read_csv('../Data/TeacherChar.csv')
talents=pd.read_csv('../Data/UserTalents.csv')
main=pd.read_csv('../Data/Main.csv')

# %%
user_traits.head()
# Out:
#    UserId      Trait
# 0       0     ACTIVE
# 1       0  ENERGETIC
# 2       0      SMART
# 3       0      QUIET
# 4       1       LAZY

# %%
teachers_characters.head()
# Out:
#    UserId      TeacherChar
# 0       1           ACTIVE
# 1       1  TEACHING SLOWLY
# 2       1             CALM
# 3       1            FUNNY
# 4       1            HAPPY

# %%
talents.head()
# Out:
#    UserId                      Talents
# 0       0                      PHYSICS
# 1       0                       CODING
# 2       0  MUSICAL INSTRUMENTS PLAYING
# 3       0                     SWIMMING
# 4       0                     SHOOTING

# %%
main['time']=pd.to_datetime(main['time'])

# %%
main.head()
# Out:
#    ID                      time age gender  \
# 0   0 2020-08-11 12:07:17-05:30  20   Male
# 1   1 2020-08-14 20:23:02-05:30  20   Male
# 2   2 2020-08-14 20:26:08-05:30  20   Male
# 3   3 2020-08-14 20:26:59-05:30  20   Male
# 4   4 2020-08-14 20:38:29-05:30  20   Male
#
#                                         student_pref  \
# 0  A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 1  A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 2  A TEACHER WHO KNOW ALL CHAPTERS OF A SUBJECT I...
# 3  A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 4  A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
#
#                                 specialization  \
# 0          Educational based on specialization
# 1  Education not based on specialization(avg.)
# 2          Educational based on specialization
# 3          Educational based on specialization
# 4            Education based on specialization
#
#                                         teacher_pref
# 0  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 1  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 2  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 3  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 4  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
