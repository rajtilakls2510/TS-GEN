# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("../Data/Phase 0(T-2) studs..csv")

# %%
df
# Out:
#                           Timestamp                       Username  \
# 0   2020/08/11 12:07:17 PM GMT+5:30        www.harryrock@gmail.com
# 1    2020/08/14 8:23:02 PM GMT+5:30       adaksritiman24@gmail.com
# 2    2020/08/14 8:26:08 PM GMT+5:30       sumitanand3098@gmail.com
# 3    2020/08/14 8:26:59 PM GMT+5:30           sumitskt39@gmail.com
# 4    2020/08/14 8:38:29 PM GMT+5:30     mukherjeesayan98@gmail.com
# ..                              ...                            ...
# 95   2020/09/27 4:26:28 PM GMT+5:30  sinhakirti250520010@gmail.com
# 96   2020/09/27 4:27:46 PM GMT+5:30      bhartikomal7010@gmail.com
# 97   2020/09/27 4:28:55 PM GMT+5:30       deymoumita1080@gmail.com
# 98   2020/09/27 4:29:55 PM GMT+5:30    muskangupta.mg111@gmail.com
# 99   2020/09/27 4:31:37 PM GMT+5:30       nidhirai189898@gmail.com
#
#                   Name Age  Gender 1.TRAITS YOU HAVE (MAXIMUM FIVE)  \
# 0                 Prem  20    Male     ACTIVE;ENERGETIC;SMART;QUIET
# 1        Sritiman Adak  20    Male             LAZY;TALKATIVE;QUIET
# 2          Sumit Anand  20    Male                  TALKATIVE;SMART
# 3   Sumit Kumar Thakur  20    Male                     ACTIVE;QUIET
# 4      sayan mukherjee  20    Male                            QUIET
# ..                 ...  ..     ...                              ...
# 95               Kirti  19  Female      TALKATIVE;FRIENDLY;CREATIVE
# 96               Komal  20  Female                         OPTIMIST
# 97             Moumita  19  Female   TALKATIVE;FRIENDLY;IMAGINATIVE
# 98              Muskan  23  Female         ACTIVE;PEACEFUL;CREATIVE
# 99               Nidhi  20  Female              LAZY;SHORT TEMPERED
#
#                        2.WHAT DO YOU PREFER THE MOST?  \
# 0   A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 1   A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 2   A TEACHER WHO KNOW ALL CHAPTERS OF A SUBJECT I...
# 3   A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 4   A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# ..                                                ...
# 95  A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 96  A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 97  A TEACHER WHO KNOWS ALL CHAPTERS OF A SUBJECT ...
# 98  A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
# 99  A TEACHER WHO KNOWS ONLY ONE CHAPTER ,BUT HE /...
#
#                              3.WHAT YOU PREFER?  \
# 0           Educational based on specialization
# 1   Education not based on specialization(avg.)
# 2           Educational based on specialization
# 3           Educational based on specialization
# 4             Education based on specialization
# ..                                          ...
# 95            Education based on specialization
# 96            Education based on specialization
# 97            Education based on specialization
# 98            Education based on specialization
# 99  Education not based on specialization(avg.)
#
#        4.CHARACTERS YOU WANT IN YOUR TEACHER(MAX SIX)  \
# 0                                                 NaN
# 1   ACTIVE;TEACHING SLOWLY;CALM;FUNNY;HAPPY;POLITE...
# 2   SERIOUS ABOUT STUDY;ACTIVE;SERIOUS ABOUT TIME;...
# 3   SERIOUS ABOUT STUDY;ACTIVE;SERIOUS ABOUT TIME;...
# 4   SERIOUS ABOUT STUDY;ACTIVE;TEACHING SLOWLY;CAL...
# ..                                                ...
# 95  SERIOUS ABOUT STUDY;ACTIVE;HUMOROUS;TALENTED;K...
# 96                                    GENTLE;TALENTED
# 97           ACTIVE;CALM;TALKATIVE;KNOWLEDGE ORIENTED
# 98  ACTIVE;SERIOUS ABOUT TIME;CALM;SMART;KNOWLEDGE...
# 99                      CALM;CURIOUS;IGNORANT;TACTFUL
#
#    5. SUPPOSE YOU ARE TEACHER ,WHAT WOULD YOU PREFER?  \
# 0   2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 1   2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 2   2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 3   2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 4   2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# ..                                                ...
# 95  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 96  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 97  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 98             1.TEACHING ALL CHAPTERS OF A SUBJECT .
# 99  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
#
#    6..WHAT DO YOU LOVE THE MOST IN LIFE?  \
# 0                                 Myself
# 1                          Staying happy
# 2                           life-lession
# 3                                    NaN
# 4                                    NaN
# ..                                   ...
# 95                            Nahi patta
# 96                                Myself
# 97                                   R.B
# 98                                   R.B
# 99                                     I
#
#                                        Unnamed: 11  \
# 0   MOODY;PEACEFUL;HAPPY;OPTIMIST;SERIOUS;IGNORANT
# 1    FRUSTATED;BORED;MOODY;PEACEFUL;HAPPY;OPTIMIST
# 2                                         PEACEFUL
# 3                                 OPTIMIST;SERIOUS
# 4                                         PEACEFUL
# ..                                             ...
# 95                                             NaN
# 96                                             NaN
# 97                                             NaN
# 98                                             NaN
# 99                                             NaN
#
#                                           Unnamed: 12  \
# 0   PHYSICS;CODING;MUSICAL INSTRUMENTS PLAYING;SWI...
# 1                    PHYSICS;CODING;SWIMMING;PAINTING
# 2   MATHS;SOCIAL STUDIES;LITERATURE;VOCAL MUSIC;WR...
# 3                                      PHYSICS;CODING
# 4                               CODING;SOCIAL STUDIES
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98                                                NaN
# 99                                                NaN
#
#                                           Unnamed: 13 Unnamed: 14
# 0   ATTENTIVE;BRILLIANT;SELF CENTRED;FRIENDLY;OBSE...         NaN
# 1    ATTENTIVE;TACTFUL;OBSERVANT;CREATIVE;IMAGINATIVE         NaN
# 2   FRIENDLY;IMAGINATIVE;WARM HEARTED(sympathetic ...         NaN
# 3                                            FRIENDLY         NaN
# 4                                           ATTENTIVE         NaN
# ..                                                ...         ...
# 95                                                NaN         NaN
# 96                                                NaN         NaN
# 97                                                NaN         NaN
# 98                                                NaN         NaN
# 99                                                NaN         NaN
#
# [100 rows x 15 columns]

# %%
df1=df.copy()

# %%
columns=['time','email','name','age','gender','physical','student_pref','specialization','teacher_char','teacher_pref','life_love','Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14']
df1.columns=columns

# %%
df1.drop(columns=['email','name','life_love', 'Unnamed: 11','Unnamed: 12','Unnamed: 13','Unnamed: 14'],inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time            100 non-null    object
#  1   age             99 non-null     object
#  2   gender          100 non-null    object
#  3   physical        100 non-null    object
#  4   student_pref    100 non-null    object
#  5   specialization  100 non-null    object
#  6   teacher_char    99 non-null     object
#  7   teacher_pref    100 non-null    object
# dtypes: object(8)
# memory usage: 6.4+ KB

# %%
df1['time']=pd.to_datetime(df1['time'])

# %%
df1['physical']=df1['physical'].str.split(';')

# %%
df1=df1.reset_index().rename(columns={'index':'ID'})

# %%
def extract_trait(traits, column):
    for trait in traits[column]:
        df2.append([traits['ID'],trait])

# %%
df2=[]
df1[['ID','physical']].apply(extract_trait, axis=1, args=('physical',))
user_traits=pd.DataFrame(df2,columns=['UserId','Trait'])

# %%
user_traits
# Out:
#      UserId           Trait
# 0         0          ACTIVE
# 1         0       ENERGETIC
# 2         0           SMART
# 3         0           QUIET
# 4         1            LAZY
# ..      ...             ...
# 323      98          ACTIVE
# 324      98        PEACEFUL
# 325      98        CREATIVE
# 326      99            LAZY
# 327      99  SHORT TEMPERED
#
# [328 rows x 2 columns]

# %%
df1['teacher_char']=df1['teacher_char'].str.split(';')

# %%
df2=[]
df1[~df1['teacher_char'].isna()][['ID','teacher_char']].apply(extract_trait, axis=1, args=('teacher_char',))
teachers_characters=pd.DataFrame(df2,columns=['UserId','TeacherChar'])

# %%
teachers_characters
# Out:
#      UserId         TeacherChar
# 0         1              ACTIVE
# 1         1     TEACHING SLOWLY
# 2         1                CALM
# 3         1               FUNNY
# 4         1               HAPPY
# ..      ...                 ...
# 673      98  KNOWLEDGE ORIENTED
# 674      99                CALM
# 675      99             CURIOUS
# 676      99            IGNORANT
# 677      99             TACTFUL
#
# [678 rows x 2 columns]

# %%
df2=[]
df1[~df1['talents'].isna()][['ID','talents']].apply(extract_trait, axis=1, args=('talents',))
talents=pd.DataFrame(df2,columns=['UserId','Talents'])

# %%
talents
# Out:
#      UserId   Talents
# 0         0     MOODY
# 1         0  PEACEFUL
# 2         0     HAPPY
# 3         0  OPTIMIST
# 4         0   SERIOUS
# ..      ...       ...
# 141      44  OPTIMIST
# 142      45  PEACEFUL
# 143      45     HAPPY
# 144      45   SERIOUS
# 145      46  OPTIMIST
#
# [146 rows x 2 columns]

# %%
df1.drop(columns=['physical','psychological','other_traits','teacher_char','talents'],inplace=True)

# %%
df1.head()
# Out:
#    ID                      time age gender  \
# 0   0 2020-08-11 12:07:17-05:30  20   Male
# 1   1 2020-08-14 20:23:02-05:30  20   Male
# 2   2 2020-08-14 20:26:08-05:30  20   Male
# 3   3 2020-08-14 20:26:59-05:30  20   Male
# 4   4 2020-08-14 20:38:29-05:30  20   Male
#
#                                         student_pref  \
# 0                                                NaN
# 1  ACTIVE;TEACHING SLOWLY;CALM;FUNNY;HAPPY;POLITE...
# 2  SERIOUS ABOUT STUDY;ACTIVE;SERIOUS ABOUT TIME;...
# 3  SERIOUS ABOUT STUDY;ACTIVE;SERIOUS ABOUT TIME;...
# 4  SERIOUS ABOUT STUDY;ACTIVE;TEACHING SLOWLY;CAL...
#
#                                       specialization  \
# 0  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 1  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 2  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 3  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
# 4  2.TEACHING ONLY CHAPTER OF A SUBJECT IN WHICH ...
#
#                                         teacher_pref
# 0  ATTENTIVE;BRILLIANT;SELF CENTRED;FRIENDLY;OBSE...
# 1   ATTENTIVE;TACTFUL;OBSERVANT;CREATIVE;IMAGINATIVE
# 2  FRIENDLY;IMAGINATIVE;WARM HEARTED(sympathetic ...
# 3                                           FRIENDLY
# 4                                          ATTENTIVE

# %%
user_traits.to_csv('../Data/UserTraits.csv',index=False)
teachers_characters.to_csv('../Data/TeacherChar.csv',index=False)
talents.to_csv('../Data/UserTalents.csv',index=False)
df1.to_csv('../Data/Main.csv',index=False)
